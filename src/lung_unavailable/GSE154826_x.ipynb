# %%
# only biological reads without technical reads

# %%
import os
from parse_soft import ParseSoft
from search_soft import SearchSoft
from enrich_soft import EnrichSoft
from label_data import LabelData

# %load_ext autoreload
# %autoreload 2

# %%
# step 1: set defaults
geo = "GSE154826"
soft_dir = '/home/yuan/data'
meta_dir = '../data'
download_dir = '/home/yuan/rawdata/SRR'

# %%
# step 2: parse soft, and enrich

# analyze soft file
parser = ParseSoft(soft_dir)
soft_path = parser.soft_local_path(geo)
print('Retrieve meta data from soft file: ', soft_path)
softer = SearchSoft(soft_path)
data = softer.filter_data(softer.parse_rows)

# save to json
LabelData(meta_dir).save(data)
# Out:
# Retrieve meta data from soft file:  /home/yuan/data/ftp.ncbi.nlm.nih.gov/geo/series/GSE154nnn/GSE154826/soft/GSE154826_family.soft.gz
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE154nnn/GSE154826/metadata.json

# %%
# step 3: enrich data
data = LabelData(meta_dir).get_meta(geo)
enriched = EnrichSoft(data)()
LabelData(meta_dir).save(enriched)
# Out:
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE154nnn/GSE154826/metadata.json

# %%
# step 4a: load sample information
import pandas as pd
xl_file = pd.ExcelFile('./constants/GSE154826.xlsx')
df = xl_file.parse('sample_table')
df.index = df['old_lib_name']
df.head()
# Out:
#               sample_ID patient_ID  amp_batch_ID old_lib_name  HTO  tissue  \
# old_lib_name
# 558T                 36        558            36         558T  NaN   Tumor
# 564N                 37        564            37         564N  NaN  Normal
# 564T                 38        564            38         564T  NaN   Tumor
# 569N                 39        569            39         569N  NaN  Normal
# 569T                 40        569            40         569T  NaN   Tumor
#
#              disease Use.in.Clustering.Model. library_chemistry  prime  \
# old_lib_name
# 558T            LUAD                      Yes                V2      3
# 564N            LUAD                      Yes                V2      3
# 564T            LUAD                      Yes                V2      3
# 569N            LUAD                      Yes                V2      3
# 569T            LUAD                      Yes                V2      3
#
#              vdj_kit   prep metadata_indicator biopsy_site
# old_lib_name
# 558T             NaN  beads                NaN         NaN
# 564N             NaN  beads                NaN         NaN
# 564T             NaN  beads                NaN         NaN
# 569N             NaN  beads                NaN         NaN
# 569T             NaN  beads                NaN         NaN

# %%
disease_info = {}
for rec in df.to_dict(orient='records'):
    d = str(rec['disease'])
    n = str(rec['patient_ID'])
    disease_info[n] = d
disease_info
# Out:
# {'558': 'LUAD',
#  '564': 'LUAD',
#  '569': 'LUAD',
#  '570': 'LUAD',
#  '571': 'LUAD',
#  '572': 'LUAD',
#  '578': 'LUAD',
#  '581': 'LUAD',
#  '584': 'LUSC',
#  '593': 'LUAD',
#  '596': 'LUAD',
#  '630': 'LUAD',
#  '626': 'LUAD',
#  '695': 'LUAD',
#  '338': 'LUAD',
#  '370': 'LUAD',
#  '371': 'LUAD',
#  '377': 'LUSC',
#  '378': 'LUAD',
#  '393': 'LUAD',
#  '403': 'LUAD',
#  '406': 'LUAD',
#  '408': 'LUAD',
#  '410': 'LUAD',
#  '458': 'LUAD',
#  '460': 'LUAD',
#  '464': 'LUAD',
#  '514': 'LUAD',
#  '522': 'LUSC',
#  '532': 'LUAD',
#  '714': 'LUSC',
#  '729': 'LUAD',
#  '725': 'LUAD',
#  '706': 'LUSC',
#  '800': 'LUAD',
#  'Lambrechts_2': 'LUSC',
#  'Lambrechts_1': 'LUSC',
#  'Lambrechts_3': 'LUAD',
#  'Lambrechts_4': 'LUAD',
#  'Lambrechts_5': 'Large cell',
#  'Lambrechts_7': 'LUSC',
#  'Lambrechts_8': 'Pleiomorphic',
#  'Lambrechts_6': 'LUAD',
#  'zilionis_1': 'LUSC',
#  'zilionis_2': 'LUSC',
#  'zilionis_3': 'LUAD',
#  'zilionis_4': 'LUAD',
#  'zilionis_5': 'LUAD',
#  'zilionis_6': 'LUAD',
#  'zilionis_7': 'LUAD'}

# %%
# step 3b: label samples manually
from label_sample import LabelSample

def collator(sample, disease_info):
    c = LabelSample(sample)
    # disease
    patient_id = c.sample['characteristics']['patient_id']
    # print(patient_id, disease_info[patient_id], end=', ')
    disease = disease_info[patient_id]
    if disease == "LUAD":
        disease = 'lung adenocarcinoma, non-small cell lung cancer'
    elif disease == 'LUSC':
        disease = 'lung squamous cell carcinoma, non-small cell lung cancer'
    c._disease(disease)
    # kit
    kit = c.sample['characteristics']["10x_chromium_encapsulation_kit"]
    if kit == "3' v2":
        c._protocol('scrna-seq', '10x3v2')
    elif kit == "5' v1":
        c._protocol('tcr-seq', '10x5v1')
    elif kit == "3' v3":
        c._protocol('scrna-seq', '10x3v3')
    
data = LabelData(meta_dir).get_meta(geo)
for sample_id, sample in data['samples'].items():
    collator(sample, disease_info)
LabelData(meta_dir).save(data)
# Out:
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE154nnn/GSE154826/metadata.json

# %%
for s in data['samples'].values():
    print(s['sample_id'], s['labels'])
# Out:
# GSM4680740 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680741 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680742 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680743 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680744 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680745 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680746 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680747 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680748 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680749 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680750 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680751 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680752 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680753 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680754 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680755 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680756 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680757 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680758 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680759 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680760 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680761 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680762 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680763 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680764 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680765 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680766 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680767 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680768 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680769 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680770 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680771 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680772 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680773 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680774 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680775 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680776 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680777 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680778 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680779 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680780 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680781 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680782 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680783 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680784 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680785 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680786 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680787 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680788 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680789 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680790 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680791 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680792 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680793 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680794 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680795 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680796 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680797 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680798 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680799 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680800 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680801 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680802 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680803 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680804 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680805 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680806 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680807 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680808 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680809 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680810 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680811 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680812 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680813 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680814 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680815 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680816 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680817 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680818 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680819 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680820 {'group': 'normal, tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680821 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680822 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680823 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680824 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680825 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680826 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680827 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680828 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680829 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680830 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680831 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680832 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680833 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680834 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680835 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680836 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680837 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680838 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680839 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680840 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680841 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680842 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680843 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680844 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680845 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680846 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680847 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680848 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680849 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680850 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680851 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680852 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680853 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}
# GSM4680854 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680855 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680856 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680857 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680858 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680859 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680860 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680861 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680862 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680863 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680864 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680865 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680866 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680867 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680868 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680869 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680870 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680871 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680872 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680873 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680874 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680875 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680876 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680877 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680878 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680879 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680880 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680881 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680882 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680883 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680884 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680885 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680886 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680887 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680888 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680889 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680890 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680891 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680892 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680893 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680894 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680895 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680896 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680897 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680898 {'group': 'normal, tumor, pbmc, spiked mouse cells', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680899 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680900 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680901 {'group': 'normal', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680902 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680903 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680904 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung squamous cell carcinoma, non-small cell lung cancer'}
# GSM4680905 {'group': 'tumor', 'tissue': 'lung', 'disease': 'lung adenocarcinoma, non-small cell lung cancer'}

# %%
# step 4a: load some data
from utils import Utils

# data are determined previously
samn_srr = Utils.from_json('../results/samn_srr.json')
print(len(samn_srr))
# Out:
# 47

# %%
# step 4b: Given BioSample, parse SRR accessions into samples
from parse_sra import ParseSra
from label_data import LabelData

data = LabelData(meta_dir).get_meta(geo)
enriched = ParseSra.parse_srr(data, samn_srr)
LabelData(meta_dir).save(enriched)
# Out:
# biosamples = 166, SRR accessions = 250.
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE154nnn/GSE154826/metadata.json

# %%
# step 5: merge srr_urls into data

# sample.<sample_id>.SRR.<SRR accession>."ftp.sra.ebi.ac.uk"
file_name = 'srr_fastq_urls_simple.json'
urls_json = os.path.join('../results', file_name)
urls = Utils.from_json(urls_json)

# parse urls
data = LabelData(meta_dir).get_meta(geo)
enriched = ParseSra.parse_srr_urls(data, urls)
LabelData(meta_dir).save(enriched)
# Out:
# {'srr': 166, 'available': 250, 'unknown': 0, 'updated': 250}
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE154nnn/GSE154826/metadata.json

# %%
# step 6a: download raw data using biosample accession using nextflow
from create_config import CreateConfig
from label_data import LabelData

sample_iter = LabelData(meta_dir).geo_sample_iter(geo)
# create bash script for downloading
CreateConfig(download_dir, geo).fetch_biosample(sample_iter)
# run the bash script showed here
# Outcome: nf download failed
# Out:
# Number of biosamples:  166
# Number of biosamples with SRR:  156
# bash /home/yuan/rawdata/SRR/GSE154826/fetch1.sh

# %%
# step 7: parse path of local fastq.gz with SRR in GEO data
# Note: run the process multiple times to make sure all SRRs are accessed
# print all samples if not any local *.fastq.gz is parsed
from parse_sra import ParseSra
from label_data import LabelData

data = LabelData(meta_dir).get_meta(geo)
data, unparsing = ParseSra.parse_local_fastq(data, download_dir)
if unparsing:
    print(geo, len(unparsing), unparsing[:6])
LabelData(meta_dir).save(data)
# Out:
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE154nnn/GSE154826/metadata.json

# %% [markdown]
# ## nf-core/scrnaseq pipeline
# create samplehseet.csv and params.config

# %%
name = 'scrnaseq_lung_tissue_patient'
output_dir = '/home/yuan/output'
labeler = LabelData(meta_dir, name, output_dir, True)

sample_sheet = {}
data = LabelData(meta_dir).get_meta(geo)
for sample, geo, run_acc, fastq_sample in labeler.fastq_iter(data):
    c = LabelSample(sample)
    print(c.filter(name), c.disease, c.tissue, sample['sample_id'])
    if c.filter(name):
        Utils.key_update(sample_sheet, [geo,], fastq_sample['sample_sheet'])
# export
if sample_sheet:
    print("Number of samples in samplesheet.csv: ", len(sample_sheet[geo]))
    labeler.to_sample_sheet(sample_sheet, 'paired')
    labeler.nf_cmd()
else:
    print(f'No samples meet creteria {name}')
# Out:
# False lung adenocarcinoma, non-small cell lung cancer lung GSM4680840
# False lung adenocarcinoma, non-small cell lung cancer lung GSM4680842
# True lung adenocarcinoma, non-small cell lung cancer lung GSM4680843
# True lung adenocarcinoma, non-small cell lung cancer lung GSM4680844
# False lung squamous cell carcinoma, non-small cell lung cancer lung GSM4680846
# False lung squamous cell carcinoma, non-small cell lung cancer lung GSM4680848
# False lung squamous cell carcinoma, non-small cell lung cancer lung GSM4680901
# False lung squamous cell carcinoma, non-small cell lung cancer lung GSM4680904
# Number of samples in samplesheet.csv:  2
# cd /home/yuan/output/scrnaseq_lung_tissue_patient/paired_GSE154826 && nextflow run nf-core/scrnaseq -r 3.0.0 -c params.config
