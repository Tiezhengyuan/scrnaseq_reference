# %%
# no paired file. only biological files
Read1 contains the cell barcode and Unique Molecule Identifier; read2 was biological reads

# %%
import os
from parse_soft import ParseSoft
from search_soft import SearchSoft
from enrich_soft import EnrichSoft
from label_data import LabelData

# %load_ext autoreload
# %autoreload 2

# %%
# step 1: set defaults
geo = "GSE167977"
soft_dir = '/home/yuan/data'
meta_dir = '../data'
download_dir = '/home/yuan/rawdata/SRR'

# %%
# step 2: parse soft, and enrich

# analyze soft file
parser = ParseSoft(soft_dir)
soft_path = parser.soft_local_path(geo)
print('Retrieve meta data from soft file: ', soft_path)
softer = SearchSoft(soft_path)
data = softer.filter_data(softer.parse_rows)

# save to json
LabelData(meta_dir).save(data)
# Out:
# Retrieve meta data from soft file:  /home/yuan/data/ftp.ncbi.nlm.nih.gov/geo/series/GSE167nnn/GSE167977/soft/GSE167977_family.soft.gz
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE167nnn/GSE167977/metadata.json

# %%
# step 3a: enrich data
data = LabelData(meta_dir).get_meta(geo)
enriched = EnrichSoft(data)()
LabelData(meta_dir).save(enriched)
# Out:
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE167nnn/GSE167977/metadata.json

# %%
# step 3b: label samples manually
from label_sample import LabelSample

def collator(sample):
    c = LabelSample(sample)
    c._protocol('scrna-seq', "10x3v2")
    c._disease_patient('breast cancer')

data = LabelData(meta_dir).get_meta(geo)
for sample_id, sample in data['samples'].items():
    collator(sample)
LabelData(meta_dir).save(data)
# Out:
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE167nnn/GSE167977/metadata.json

# %%
for sample_id, sample in data['samples'].items():
    print(sample['sample_title'], sample['labels'])
# Out:
# MATADOR_RNAseq_X158 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X184 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X191 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X203 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X205 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X229 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X234 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X247 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X253 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X269 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X270 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X284 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X307 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X308 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X315 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X316 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X327 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X328 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X342 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X345 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X352 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X353 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X362 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X385 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X395 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X396 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X397 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X406 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X407 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X422 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X454 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X468 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X483 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X485 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X490 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X496 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X503 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X514 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X520 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X524 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X528 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X549 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X65 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X76 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X116 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X130 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X14 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X15 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X193 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X208 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X211 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X212 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X221 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X226 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X227 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X235 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X250 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X259 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X267 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X286 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X291 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X29 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X318 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X31 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X323 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X333 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X343 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X371 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X375 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X376 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X416 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X417 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X446 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X480 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X531 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X535 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X544 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X563 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X564 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X576 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X647 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X648 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X87 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X89 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X117 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X118 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X132 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X133 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X137 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X140 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X16 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X174 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X175 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X17 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X213 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X214 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X215 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X216 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X23 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X254 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X255 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X279 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X281 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X290 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X325 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X329 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X32 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X337 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X338 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X33 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X367 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X368 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X418 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X420 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X429 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X430 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X449 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X453 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X529 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X530 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X570 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X605 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X608 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X649 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X651 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X66 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X90 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X91 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x ac dd', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X94 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_
{'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}
# MATADOR_RNAseq_X80 {'tissue': 'primairy tumor before treatment ffpe', 'treatment': '6 x tac', 'disease': 'breast cancer', 'group': 'patient'}

# %%
# step 4a: load some data
from utils import Utils

# data are determined previously
samn_srr = Utils.from_json('../results/samn_srr.json')
print(len(samn_srr))
# Out:
# 47

# %%
# step 4b: Given BioSample, parse SRR accessions into samples
from parse_sra import ParseSra
from label_data import LabelData

data = LabelData(meta_dir).get_meta(geo)
enriched = ParseSra.parse_srr(data, samn_srr)
LabelData(meta_dir).save(enriched)
# Out:
# biosamples = 528, SRR accessions = 528.
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE167nnn/GSE167977/metadata.json

# %%
# step 5: merge srr_urls into data

# sample.<sample_id>.SRR.<SRR accession>."ftp.sra.ebi.ac.uk"
file_name = 'srr_fastq_urls_simple.json'
urls_json = os.path.join('../results', file_name)
urls = Utils.from_json(urls_json)

# parse urls
data = LabelData(meta_dir).get_meta(geo)
enriched = ParseSra.parse_srr_urls(data, urls)
LabelData(meta_dir).save(enriched)
# Out:
# {'srr': 528, 'available': 0, 'unknown': 528, 'updated': 0}
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE167nnn/GSE167977/metadata.json

# %%
# step 6a: download raw data using biosample accession using nextflow
from create_config import CreateConfig
from label_data import LabelData

sample_iter = LabelData(meta_dir).geo_sample_iter(geo)
# create bash script for downloading
CreateConfig(download_dir, geo).fetch_biosample(sample_iter)
# run the bash script showed here
# Outcome: nf download failed
# Out:
# Number of biosamples:  528
# Number of biosamples with SRR:  528
# bash /home/yuan/rawdata/SRR/GSE167977/fetch1.sh

# %%
#Step 6b: collect all SRR without local_fastq then execute bash run2.sh
from create_config import CreateConfig
from label_data import LabelData

sample_iter = LabelData(meta_dir).geo_sample_iter(geo)
# create bash script for downloading
CreateConfig(download_dir, geo).fetch_ebi_srr(sample_iter)
# run the bash script showed here
# Out:
# Number of SRR:  528
# bash /home/yuan/rawdata/SRR/GSE167977/fetch2.sh

# %%
#Step 6c: collect all SRR without local_fastq then execute bash run3.sh
from create_config import CreateConfig
from label_data import LabelData

sample_iter = LabelData(meta_dir).geo_sample_iter(geo)
# create bash script for downloading
CreateConfig(download_dir, geo).fetch_srr(sample_iter)
# run the bash script showed here
# Out:
# Number of SRR:  528
# bash /home/yuan/rawdata/SRR/GSE167977/fetch3.sh

# %%
# step 7: parse path of local fastq.gz with SRR in GEO data
# Note: run the process multiple times to make sure all SRRs are accessed
# print all samples if not any local *.fastq.gz is parsed
from parse_sra import ParseSra
from label_data import LabelData

data = LabelData(meta_dir).get_meta(geo)
data, unparsing = ParseSra.parse_local_fastq(data, download_dir)
if unparsing:
    print(geo, len(unparsing), unparsing[:6])
LabelData(meta_dir).save(data)
# Out:
# GSE167977 528 ['SRR13816316', 'SRR13816317', 'SRR13816318', 'SRR13816319', 'SRR13816320', 'SRR13816321']
# Save meta data into json:  /home/yuan/bio/scrnaseq_reference/data/labels/GSE167nnn/GSE167977/metadata.json
